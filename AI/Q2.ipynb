# %%
n = int(input("Enter n: "))
count = 0
print("Even numbers: ")
for i in range(2, n + 1, 2):
    print(i)
    count += 1
print("\nTotal even numbers:", count)
# Out:
# Enter n: 10
# Even numbers:
# 2
# 4
# 6
# 8
# 10
#
# Total even numbers: 5
